# %% [markdown]
# <a href="https://colab.research.google.com/github/cwangerin/539/blob/master/Ex_0909P1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-c46ca30a-911a-4424-9d7f-5e40e9221eaf" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c46ca30a-911a-4424-9d7f-5e40e9221eaf">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving iris.csv to iris.csv

# %%
import io
iris = pd.read_csv(io.BytesIO(uploaded['iris.csv']))
iris.columns = ['sepal_length','sepal_width','petal_length','petal_width','type']

# %%
iris_setosa=iris.loc[iris["type"]=="Iris-setosa"]
iris_virginica=iris.loc[iris["type"]=="Iris-virginica"]
iris_versicolor=iris.loc[iris["type"]=="Iris-versicolor"]

# %%
print(len(iris_setosa))
print(len(iris_setosa.columns))
print(iris_setosa.describe())
# Out:
# 49
# 5
#        sepal_length  sepal_width  petal_length  petal_width
# count     49.000000    49.000000     49.000000    49.000000
# mean       5.004082     3.416327      1.465306     0.244898
# std        0.355879     0.384787      0.175061     0.108130
# min        4.300000     2.300000      1.000000     0.100000
# 25%        4.800000     3.100000      1.400000     0.200000
# 50%        5.000000     3.400000      1.500000     0.200000
# 75%        5.200000     3.700000      1.600000     0.300000
# max        5.800000     4.400000      1.900000     0.600000

# %%
print(len(iris_versicolor))
print(len(iris_versicolor.columns))
print(iris_versicolor.describe())
# Out:
# 50
# 5
#        sepal_length  sepal_width  petal_length  petal_width
# count     50.000000    50.000000     50.000000    50.000000
# mean       5.936000     2.770000      4.260000     1.326000
# std        0.516171     0.313798      0.469911     0.197753
# min        4.900000     2.000000      3.000000     1.000000
# 25%        5.600000     2.525000      4.000000     1.200000
# 50%        5.900000     2.800000      4.350000     1.300000
# 75%        6.300000     3.000000      4.600000     1.500000
# max        7.000000     3.400000      5.100000     1.800000

# %%
print(len(iris_virginica))
print(len(iris_virginica.columns))
print(iris_virginica.describe())
# Out:
# 50
# 5
#        sepal_length  sepal_width  petal_length  petal_width
# count      50.00000    50.000000     50.000000     50.00000
# mean        6.58800     2.974000      5.552000      2.02600
# std         0.63588     0.322497      0.551895      0.27465
# min         4.90000     2.200000      4.500000      1.40000
# 25%         6.22500     2.800000      5.100000      1.80000
# 50%         6.50000     3.000000      5.550000      2.00000
# 75%         6.90000     3.175000      5.875000      2.30000
# max         7.90000     3.800000      6.900000      2.50000

# %%
import seaborn as sns

# %%
sns.pairplot(iris,hue="type", diag_kind="none")
